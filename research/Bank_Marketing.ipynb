# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Loading and cleaning data

# %%
df = pd.read_csv("/content/bank-additional-full.csv", delimiter = ";")

# %%
print(df.shape)
df.head()
# Out:
# (41188, 21)
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
df.sample(5)
# Out:
#        age          job  marital            education  default  housing  \
# 13498   39  blue-collar  married             basic.9y       no      yes
# 34704   51   technician  married  professional.course       no  unknown
# 15707   54  blue-collar  married             basic.4y       no       no
# 8598    38  blue-collar  married             basic.6y  unknown       no
# 16631   37  blue-collar  married             basic.9y       no      yes
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 13498       no   cellular   jul         thu  ...         1    999         0
# 34704  unknown   cellular   may         thu  ...         2    999         1
# 15707       no   cellular   jul         mon  ...         1    999         0
# 8598        no  telephone   jun         wed  ...         1    999         0
# 16631       no   cellular   jul         wed  ...        12    999         0
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df [df.duplicated()]
# Out:
#        age          job   marital            education  default housing loan  \
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14234   27   technician    single  professional.course       no      no   no
# 16956   47   technician  divorced          high.school       no     yes   no
# 18465   32   technician    single  professional.course       no     yes   no
# 20216   55     services   married          high.school  unknown      no   no
# 20534   41   technician   married  professional.course       no     yes   no
# 25217   39       admin.   married    university.degree       no      no   no
# 28477   24     services    single          high.school       no     yes   no
# 32516   35       admin.   married    university.degree       no     yes   no
# 36951   45       admin.   married    university.degree       no      no   no
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# age                 78
# job                 12
# marital              4
# education            8
# default              3
# housing              3
# loan                 3
# contact              2
# month               10
# day_of_week          5
# duration          1544
# campaign            42
# pdays               27
# previous             8
# poutcome             3
# emp.var.rate        10
# cons.price.idx      26
# cons.conf.idx       26
# euribor3m          316
# nr.employed         11
# y                    2
# dtype: int64

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
df.describe(include = 'object')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41176    41176              41176   41176   41176  41176     41176
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10419    24921              12164   32577   21571  33938     26135
#
#         month day_of_week     poutcome      y
# count   41176       41176        41176  41176
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13767        8618        35551  36537

# %% [markdown]
# # Basic Info of Columns

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 10 numerical features : ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
#
# We have 11 categorical features : ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y']

# %%
for cat in categorical_features:
  print(f"Categories in '{cat}' variable are '{df[cat].nunique()}':     ",end=" " )
  print(df[cat].unique())
# Out:
# Categories in 'job' variable are '12':      ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
# Categories in 'marital' variable are '4':      ['married' 'single' 'divorced' 'unknown']
# Categories in 'education' variable are '8':      ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
# Categories in 'default' variable are '3':      ['no' 'unknown' 'yes']
# Categories in 'housing' variable are '3':      ['no' 'yes' 'unknown']
# Categories in 'loan' variable are '3':      ['no' 'yes' 'unknown']
# Categories in 'contact' variable are '2':      ['telephone' 'cellular']
# Categories in 'month' variable are '10':      ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
# Categories in 'day_of_week' variable are '5':      ['mon' 'tue' 'wed' 'thu' 'fri']
# ...

# %% [markdown]
# # Filling Missing Values

# %%
import pandas as pd
from tabulate import tabulate
# Assuming you have a DataFrame called 'df' and a list of categorical features called 'categorical_features'

# Create an empty list to store the tables for each categorical feature
tables = []

for cat in categorical_features:
    # Calculate value counts as percentages
    value_counts_percent = df[cat].value_counts(normalize=True).mul(100).round(2)

    # Convert the result to a DataFrame for tabulation
    table_df = pd.DataFrame({'Categories': value_counts_percent.index, 'Count': df[cat].value_counts(), 'Percentage %': value_counts_percent })

    # Create a custom function to format the entire row
    def format_row(row):
        if row['Categories'] == 'unknown':
            return [f"\033[1;31m{col}\033[0m" for col in row]
        else:
            return row

    # Apply the custom formatting function to each row
    table_df = table_df.apply(format_row, axis=1)

    # Convert the DataFrame to a string with tabulate
    table_str = tabulate(table_df, headers='keys', tablefmt='pretty', showindex=False)

    # Append the table string to the list
    tables.append((cat, table_str))

# Print each table
for cat, table_str in tables:
    print(f"Category Column: {cat}\n")
    print(table_str)
    print("\n\n")
# Out:
# Category Column: job
#
# +---------------+-------+--------------+
# |  Categories   | Count | Percentage % |
# +---------------+-------+--------------+
# |    admin.     | 10419 |     25.3     |
# |  blue-collar  | 9253  |    22.47     |
# |  technician   | 6739  |    16.37     |
# |   services    | 3967  |     9.63     |
# |  management   | 2924  |     7.1      |
# |    retired    | 1718  |     4.17     |
# | entrepreneur  | 1456  |     3.54     |
# | self-employed | 1421  |     3.45     |
# |   housemaid   | 1060  |     2.57     |
# |  unemployed   | 1014  |     2.46     |
# |    student    |  875  |     2.13     |
# |    unknown    |  330  |     0.8      |
# +---------------+-------+--------------+
#
#
#
# Category Column: marital
#
# +------------+-------+--------------+
# | Categories | Count | Percentage % |
# +------------+-------+--------------+
# |  married   | 24921 |    60.52     |
# |   single   | 11564 |    28.08     |
# |  divorced  | 4611  |     11.2     |
# ...

# %%
df = df.replace('unknown', np.NaN)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41176 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             40846 non-null  object
#  2   marital         41096 non-null  object
#  3   education       39446 non-null  object
#  4   default         32580 non-null  object
#  5   housing         40186 non-null  object
#  6   loan            40186 non-null  object
#  7   contact         41176 non-null  object
#  8   month           41176 non-null  object
#  9   day_of_week     41176 non-null  object
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  object
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# age                  0
# job                330
# marital             80
# education         1730
# default           8596
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# dtype: int64

# %%
df = df.drop(['default'], axis = 1)

# %%
 df = df.fillna(df.mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %% [markdown]
# # Visual EDA

# %% [markdown]
# ## Categorical Variables

# %% [markdown]
# ### Univariate Analysis

# %%
fig, ax = plt.subplots(len(categorical_features), 2, figsize=(15, 6 * len(categorical_features)))
ax = ax.flat
for i, cat in enumerate(categorical_features):
  i =  i<<1
  result = df[cat].value_counts()
  sns.countplot(x= cat,data=df,order = result.index,palette = 'bright',ax=ax[i],saturation=0.70)
  if len(df[cat].unique()) > 5:
    ax[i].tick_params(axis='x', rotation=45)
  for p in ax[i].patches:
    ax[i].annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                       textcoords='offset points')

  ax[i+1].pie(result.values, labels = result.index, explode = [0.5  if col == 'unknown' else 0 for col in result.index ],autopct ='%.2f%%', shadow = True, radius=2)
  ax[i+1].set_title(cat, fontsize = 20)
  ax[i+1].axis('off')
  plt.tight_layout()

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.subplots(figsize = (15,5))
for cat in categorical_features[:-1]:
  result = df[cat].value_counts(normalize = True).mul(100).round(2)
  ax = sns.countplot(x=cat,data=df, hue = 'y',order = result.index , palette=['#432371',"#FAAE7B"], saturation=0.70, hue_order = ['yes', 'no'])
  if len(df[cat].unique()) > 5:
    ax.tick_params(axis='x', rotation=45)


  '''
    total_height = len(df[cat])
    for p in ax.patches:
      height = p.get_height()
      percentage = height / total_height * 100  # Calculate percentage
      ax.annotate(f'{percentage:.2f}%', (p.get_x() + p.get_width() / 2., height),
                  ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                  textcoords='offset points')'''

  plt.tight_layout()
  plt.show()

# %%
plt.subplots(figsize = (15,5))
for cat in categorical_features:
  result = df[df['y'] == 'yes'][cat].value_counts()
  ax = sns.countplot(x=cat,data=df[df['y'] == 'yes'],order = result.index, palette=['#432371'], saturation=0.70)
  if len(df[cat].unique()) > 5:
    ax.tick_params(axis='x', rotation=45)
  for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                       textcoords='offset points')

  plt.title(f"Number Of People Subscribed Term Deposit in: {cat}")
  plt.tight_layout()
  plt.show()

# %% [markdown]
# ## Numerical Variables

# %% [markdown]
# ### Univariate Analysis

# %%
for col in numeric_features:
    print(col)
    print('Skew :', round(df[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.show()
# Out:
# age
# Skew : 0.78
# duration
# Skew : 3.26
# campaign
# Skew : 4.76
# pdays
# Skew : -4.92
# previous
# Skew : 3.83
# emp.var.rate
# Skew : -0.72
# cons.price.idx
# Skew : -0.23
# cons.conf.idx
# Skew : 0.3
# euribor3m
# Skew : -0.71
# nr.employed
# Skew : -1.04

# %%
from scipy.stats import zscore
outliers = df[(np.abs(zscore(df[numeric_features])) > 3).all(axis=1)]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []

# %%
df[(np.abs(zscore(df['duration'])) > 3)]
# Out:
#        age           job   marital            education housing loan  \
# 37      52    technician   married             basic.9y     yes   no
# 75      41   blue-collar  divorced             basic.4y     yes   no
# 83      49  entrepreneur   married    university.degree     yes   no
# 88      49    technician   married             basic.9y      no   no
# 164     39      services  divorced          high.school      no   no
# ...    ...           ...       ...                  ...     ...  ...
# 40880   28        admin.    single          high.school      no   no
# 40970   24        admin.    single    university.degree     yes   no
# 41121   46        admin.    single    university.degree     yes   no
# 41123   36   blue-collar    single             basic.6y      no   no
# 41164   54        admin.   married  professional.course      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# ...

# %%
df[(np.abs(zscore(df['duration'])) <= 3)]
# Out:
#        age          job  marital            education housing loan    contact  \
# 0       56    housemaid  married             basic.4y      no   no  telephone
# 1       57     services  married          high.school      no   no  telephone
# 2       37     services  married          high.school     yes   no  telephone
# 3       40       admin.  married             basic.6y      no   no  telephone
# 4       56     services  married          high.school      no  yes  telephone
# ...    ...          ...      ...                  ...     ...  ...        ...
# 41183   73      retired  married  professional.course     yes   no   cellular
# 41184   46  blue-collar  married  professional.course      no   no   cellular
# 41185   56      retired  married    university.degree     yes   no   cellular
# 41186   44   technician  married  professional.course      no   no   cellular
# 41187   74      retired  married  professional.course     yes   no   cellular
#
# ...

# %% [markdown]
# ### Bivariate Analysis

# %%
for col in numeric_features:
  sns.displot(data=df, x=col, hue="y", kind="kde", fill=True)

# %%
 for col in numeric_features:
  sns.catplot(data=df, x=col, y="y", kind="box")

# %%
import scipy.stats as stats
def univariateAnalysis_numeric1(column):
    print("\nDescription of " + column)
    print("----------------------------------------------------------------------------")
    print(df[column].describe(),end=' ')

    print("\nCentral values of " + column)
    print("----------------------------------------------------------------------------")
    #Central values
    print('\nMinimum : ', df[column].min(),end=' ')
    print('\nMaximum : ', df[column].max(),end=' ')
    print('\nMean value : ', df[column].mean(),end=' ')
    print('\nMedian value : ', df[column].median(),end=' ')
    print('\nStandard deviation : ', df[column].std(),end=' ')
    print('\nNull values : ', df[column].isnull().any(),end=' ')
    print('\nNull values : ', df[column].isnull().sum().sum(),end=' ')

    print("\nQuartile of " + column)
    print("----------------------------------------------------------------------------")
    #Quartiles
    Q1=df[column].quantile(q=0.25)
    Q3=df[column].quantile(q=0.75)
    print('1st Quartile (Q1) is: ', Q1)
    print('3st Quartile (Q3) is: ', Q3)
    print('Interquartile range (IQR) is ', stats.iqr(df[column]))

    print("\nOutlier detection from Interquartile range (IQR) " + column)
    print("----------------------------------------------------------------------------")
    L_outliers=Q1-1.5*(Q3-Q1)
    U_outliers=Q3+1.5*(Q3-Q1)
    print('\nLower outliers range: ', L_outliers)
    print('\nUpper outliers range: ', U_outliers)
    print('Number of outliers in upper : ', df[df[column]>U_outliers][column].count())
    print('Number of outliers in lower : ', df[df[column]<L_outliers][column].count())
    print('% of Outlier in upper: ',round(df[df[column]>U_outliers][column].count()*100/len(df)), '%')
    print('% of Outlier in lower: ',round(df[df[column]<L_outliers][column].count()*100/len(df)), '%')

    #boxplot
    plt.figure()
    print("\nBoxPlot of " + column)
    print("----------------------------------------------------------------------------")
    ax = sns.boxplot(x=df[column])
    plt.show()

    #distplot
    plt.figure()
    print("\ndistplot of " + column)
    print("----------------------------------------------------------------------------")
    sns.distplot(df[column])
    plt.show()

    #histogram
    plt.figure()
    print("\nHistogram of " + column)
    print("----------------------------------------------------------------------------")
    sns.distplot(df[column], kde=False, color='red')
    plt.show()

    # Plotting mean, median and mode
    plt.figure()
    print("\nHistogram with mean, median and mode of " + column)
    print("----------------------------------------------------------------------------")
    mean=df[column].mean()
    median=df[column].median()
    mode=df[column].mode()

    print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])
    plt.hist(df[column],bins=100,color='lightblue') #Plot the histogram
    plt.axvline(mean,color='green',label='Mean')     # Draw lines on the plot for mean median and the two modes we have in GRE Score
    plt.axvline(median,color='blue',label='Median')
    plt.axvline(mode[0],color='red',label='Mode1')
    plt.legend()              # Plot the legend
    plt.show()

    print("\nSkewness of " + column)
    print("----------------------------------------------------------------------------")

    print(df[column].skew())

    fig, (ax1)=plt.subplots(1,0,figsize=(13,5))

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
lstnumericcolumns = list(df_num.columns.values)
len(lstnumericcolumns)
# Out:
# 10

# %%
lstnumericcolumns
# Out:
# ['age',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
'''
for column in lstnumericcolumns:
univariateAnalysis_numeric1(column)
'''
# Out:
# '\nfor column in lstnumericcolumns:\nunivariateAnalysis_numeric1(column)\n'

# %% [markdown]
# ### MutliaVariate Analysis

# %%
# sns.pairplot(df, hue = 'y', diag_kind='kde',kind='reg')

# %%
df.corr().T
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000808  0.004622 -0.034381  0.024379
# duration       -0.000808  1.000000 -0.071765 -0.047556  0.020600
# campaign        0.004622 -0.071765  1.000000  0.052606 -0.079182
# pdays          -0.034381 -0.047556  0.052606  1.000000 -0.587508
# previous        0.024379  0.020600 -0.079182 -0.587508  1.000000
# emp.var.rate   -0.000242 -0.027941  0.150786  0.271063 -0.420587
# cons.price.idx  0.001009  0.005303  0.127826  0.078920 -0.203197
# cons.conf.idx   0.129075 -0.008126 -0.013657 -0.091374 -0.050929
# euribor3m       0.010852 -0.032861  0.135169  0.296946 -0.454571
# nr.employed    -0.017607 -0.044672  0.144129  0.372659 -0.501411
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.000242        0.001009       0.129075   0.010852
# duration           -0.027941        0.005303      -0.008126  -0.032861
# ...

# %%
plt.figure(figsize = (15, 7))
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
ax = sns.heatmap(df.corr(), cmap = sns.diverging_palette( 10, 220, as_cmap=True) ,annot = True, fmt=".1f", linewidths=.5, center = 0, mask = mask)

# %% [markdown]
# # Encoding Categorical Features and Normalizing Numerical Features

# %%
categorical_features.remove('y')

# %%
categorical_features
# Out:
# ['job',
#  'marital',
#  'education',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

numeric_transformer = StandardScaler()
oh_transformer = OneHotEncoder()

preprocessor = ColumnTransformer(
    [
        ("OneHotEncoder", oh_transformer, categorical_features),
         ("StandardScaler", numeric_transformer, numeric_features),
    ]
)
encoder = TargetEncoder()

# %%
X = df.drop(columns=['y'],axis=1)

# %%
df['y'] = df['y'].replace({'yes': 1, 'no': 0})

# %%
y = df['y']

# %%
from sklearn.model_selection import train_test_split
X_train_temp, X_test, y_train_temp, y_test = train_test_split(X,y,stratify = y, test_size=0.20,random_state=42)
X_train_temp.shape, X_test.shape
# Out:
# ((32940, 19), (8236, 19))

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train_temp,y_train_temp,stratify = y_train_temp, test_size=0.25,random_state=42)
X_train.shape, X_valid.shape
# Out:
# ((24705, 19), (8235, 19))

# %%
X_train_encoded = encoder.fit_transform(X_train, y_train)
X_valid_encoded = encoder.transform(X_valid, y_valid)
X_test_encoded = encoder.transform(X_test, y_test)
X_encoded =  encoder.transform(X, y)

# %%
X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
X_test = preprocessor.transform(X_test)
X = preprocessor.transform(X)

# %% [markdown]
# # Sampling Data

# %%
df['y'].value_counts(normalize = True).mul(100).round(2)
# Out:
# 0    88.73
# 1    11.27
# Name: y, dtype: float64

# %%
sns.set(style="whitegrid")
ax = sns.countplot(data=df, x='y', palette='bright', saturation=0.70)

# Annotate the bars with their counts
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# # Modelling Data

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report

# %%
def evaluate_classification_model(X, y, X_train, y_train, X_valid, y_valid, X_test, y_test, X_encoded, X_train_encoded, X_valid_encoded , X_test_encoded, models, params, cv=3, n_iter=5):
  results = []  # List to store dictionaries of results and their metrics
  classifier = {}
  for model_name, model in models.items():
    param = params[model_name]
    if model_name == 'CatBoost Classifier':
      rs = RandomizedSearchCV(model, param_distributions=param, scoring="recall", cv=cv, n_iter=n_iter)
      rs.fit(X_encoded, y)
      best_params = rs.best_params_
      classifier[model_name] = model

      model.set_params(**best_params)

      model.fit(X_train_encoded, y_train)

      y_train_pred = model.predict(X_train_encoded)
      y_valid_pred = model.predict(X_valid_encoded)
      y_test_pred = model.predict(X_test_encoded)

    else:
      rs = RandomizedSearchCV(model, param_distributions=param, scoring="recall", cv=cv, n_iter=n_iter)
      rs.fit(X, y)
      best_params = rs.best_params_
      classifier[model_name] = model

      model.set_params(**best_params)

      model.fit(X_train, y_train)

      y_train_pred = model.predict(X_train)
      y_valid_pred = model.predict(X_valid)
      y_test_pred = model.predict(X_test)

    accuracy_train = round(accuracy_score(y_train, y_train_pred), 2)
    accuracy_valid = round(accuracy_score(y_valid, y_valid_pred), 2)
    accuracy_test = round(accuracy_score(y_test, y_test_pred), 2)

    precision_train = round(precision_score(y_train, y_train_pred), 2)
    precision_valid = round(precision_score(y_valid, y_valid_pred), 2)
    precision_test = round(precision_score(y_test, y_test_pred), 2)

    recall_train = round(recall_score(y_train, y_train_pred), 2)
    recall_valid = round(recall_score(y_valid, y_valid_pred), 2)
    recall_test = round(recall_score(y_test, y_test_pred), 2)

    f1_train = round(f1_score(y_train, y_train_pred), 2)
    f1_valid = round(f1_score(y_valid, y_valid_pred), 2)
    f1_test = round(f1_score(y_test, y_test_pred), 2)





    model_metrics = {
        'Model': model_name,
        'Metrics': {
            'Train': {'Accuracy': accuracy_train, 'Precision': precision_train, 'Recall': recall_train, 'F1 Score': f1_train},
            'Validation': {'Accuracy': accuracy_valid, 'Precision': precision_valid, 'Recall': recall_valid, 'F1 Score': f1_valid},
            'Test': {'Accuracy': accuracy_test, 'Precision': precision_test, 'Recall': recall_test, 'F1 Score': f1_test},
        },
        'Best Parameters': best_params
    }

    # Append the model metrics dictionary to the list of classifiers
    results.append(model_metrics)
    # Create a DataFrame from the list of classifiers
    results_df = pd.DataFrame(results)

    # Extract metrics from the nested 'Metrics' dictionary and flatten the structure
    metrics_df = pd.concat([results_df['Metrics'].apply(lambda x: x[key]).apply(pd.Series).add_prefix(key + ' ') for key in ['Train', 'Validation', 'Test']], axis=1)

    # Concatenate extracted metrics with the original DataFrame and rearrange columns
    results_df = pd.concat([results_df.drop(['Metrics'], axis=1), metrics_df], axis=1)[
        ['Model', 'Train Accuracy', 'Train Precision', 'Train Recall', 'Train F1 Score',
        'Validation Accuracy', 'Validation Precision', 'Validation Recall', 'Validation F1 Score',
        'Test Accuracy', 'Test Precision', 'Test Recall', 'Test F1 Score', 'Best Parameters']]

    # Round numerical columns for neatness
    results_df = results_df.round(2)

    # Reset the index for a clean DataFrame
    results_df.reset_index(drop=True, inplace=True)

  return results_df, classifier

# %%
if recall_test > best_recall:
            best_recall = recall_test
            best_model_name = model_name

        best_model = models[best_model_name]
        best_model_params = best_params
if best_recall < 0.60:
      print('no best model found')
    else:
      print("Best Model :", best_model)
      print("Best Recall", best_recall)
      print("Best model parameters: ", best_model_params)

# %%
pip install catboost

# %%
pip install category_encoders

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.naive_bayes import GaussianNB
from scipy.stats import randint, uniform

# Assuming you have your data split into X_train, X_test, y_train, and y_test

models = {
    "Logistic Regression": LogisticRegression(),
    "K-Neighbors Classifier": KNeighborsClassifier(),
    "Support Vector Classifier": SVC(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "AdaBoost Classifier": AdaBoostClassifier(),
    "XGBoost Classifier": XGBClassifier(scale_pos_weight=float(np.sum(y_train == 0)) /(3*np.sum(y_train == 1))),
    "CatBoost Classifier": CatBoostClassifier(verbose=False)
}


params ={
        "Logistic Regression": {
            'penalty':['l1', 'l2'],
            'C':[0.01, 0.03, 0.1, 1, 10]
        },
        "K-Neighbors Classifier": {
            'n_neighbors': np.arange(13,50).tolist()
        },
        "Support Vector Classifier": {
            'C': [0.1, 1],
            'kernel': ['linear', 'rbf'],
            'gamma': [0.1, 1]
        },
        "Naive Bayes":{
            'var_smoothing': np.logspace(-9, 0, 100)
        },
        "Decision Tree": {
            'criterion':['gini', 'entropy', 'log_loss'],
            'splitter':['best','random'],
            'max_features':['sqrt','log2'],
            'class_weight':['balanced'],
            'min_weight_fraction_leaf': [0.01]
        },
        "Random Forest": {
            'n_estimators': [100, 200, 300],  # Try different numbers of trees
            'criterion': ['gini'],
            'max_features': ['sqrt', 'log2'],
            'max_depth': [None, 10, 20],  # Limit the maximum depth of trees
            'min_samples_split': [2, 5, 10],  # Adjust minimum samples split
            'min_samples_leaf': [1, 2, 4]  # Adjust minimum leaf samples

        },
        "AdaBoost Classifier": {
            'n_estimators': [64,128,256],
            'learning_rate': [0.001, 0.01, 0.1]
        },
        "XGBoost Classifier": {

             'learning_rate': [0.1, 0.01, 0.05, 0.001],
              'n_estimators': [8, 16, 32, 64, 128, 256],
              'max_depth': randint(3, 19),  # Random integer between 3 and 18
              'gamma': uniform(1, 9),  # Random float between 1 and 10
              'reg_alpha': randint(40, 181),  # Random integer between 40 and 180
              'reg_lambda': uniform(0, 1),  # Random float between 0 and 1
              'colsample_bytree': uniform(0.5, 0.5),  # Random float between 0.5 and 1
              'min_child_weight': randint(0, 11)  # Random integer between 0 and 10

             'learning_rate':[0.1,.01,.05,.001],
             'n_estimators': [8,16,32,64,128,256]

        },
        "CatBoost Classifier": {
            'iterations': np.arange(100, 1300, 100).tolist(),
            'learning_rate': [0.001, 0.004, 0.01, 0.1, 0.2, 0.3],
            'depth': np.arange(1, 11).tolist(),
            'l2_leaf_reg': [1, 3, 5, 7, 9],
            'boosting_type': ['Ordered', 'Plain']
        }
        }

# %%
results_df, classifier = evaluate_classification_model(X, y, X_train, y_train, X_valid, y_valid, X_test, y_test, X_encoded, X_train_encoded, X_valid_encoded , X_test_encoded, models, params, cv=3, n_iter=5)

# %%
results_df
# Out:
#                        Model  Train Accuracy  Train Precision  Train Recall  \
# 0        Logistic Regression            0.91             0.67          0.41
# 1     K-Neighbors Classifier            0.91             0.68          0.35
# 2  Support Vector Classifier            0.90             0.66          0.29
# 3                Naive Bayes            0.87             0.43          0.50
# 4              Decision Tree            0.80             0.31          0.64
# 5              Random Forest            0.92             0.85          0.31
# 6        AdaBoost Classifier            0.91             0.66          0.36
# 7         XGBoost Classifier            0.90             0.53          0.77
# 8        CatBoost Classifier            0.91             0.69          0.41
#
#    Train F1 Score  Validation Accuracy  Validation Precision  \
# 0            0.51                 0.91                  0.67
# 1            0.46                 0.91                  0.67
# ...

# %%
results_df = results_df[["Model", "Train Accuracy", "Validation Accuracy", "Test Accuracy",
     "Train Precision", "Validation Precision", "Test Precision",
     "Train Recall", "Validation Recall", "Test Recall",
     "Train F1 Score", "Validation F1 Score", "Test F1 Score",
     "Best Parameters"]]

# %%
# Save DataFrame to Excel file in Colab
results_df.to_excel('results1.xlsx', index=False)
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
classifier
# Out:
# {'Logistic Regression': LogisticRegression(),
#  'K-Neighbors Classifier': KNeighborsClassifier(),
#  'Support Vector Classifier': SVC(),
#  'Naive Bayes': GaussianNB(),
#  'Decision Tree': DecisionTreeClassifier(),
#  'Random Forest': RandomForestClassifier(),
#  'AdaBoost Classifier': AdaBoostClassifier(),
#  'XGBoost Classifier': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
classifier['Logistic Regression'].coef_
# Out:
# array([[-0.01890262, -0.31241432, -0.24272054,  0.03707432, -0.12252546,
#          0.34859574, -0.11120694, -0.19256196,  0.1758542 , -0.01492675,
#         -0.13399378, -0.21642689, -0.22801969, -0.14328155, -0.212412  ,
#         -0.09243388, -0.30985919, -0.20767848,  0.43156286, -0.10465643,
#         -0.09225101, -0.27588364, -0.31184449, -0.3108964 , -0.27683173,
#         -0.00334827, -0.58437986, -0.21475611,  0.37900999, -0.03338778,
#         -0.13555712, -0.53250326,  1.57139242, -0.80391819, -0.5794904 ,
#         -0.21910528, -0.0194124 , -0.09465657, -0.24260695, -0.14208839,
#         -0.1000883 , -0.00828792, -0.69845022, -0.33692028,  0.44764237,
#         -0.01730413,  1.22504051, -0.1010386 , -0.14908927, -0.04541478,
#         -2.17573404,  0.92757465,  0.09730331,  0.58887325,  0.01774908]])

# %%
coefficients = classifier['Logistic Regression'].coef_.flatten()
feature_names = classifier['Logistic Regression'].feature_names_in_  # Replace these with your actual feature names

# Plotting the coefficients with feature names
plt.figure(figsize=(10, 6))
plt.barh(range(len(feature_names)), coefficients, align='center', color='skyblue')
plt.yticks(range(len(feature_names)), feature_names)
plt.xlabel('Coefficient Value')
plt.ylabel('Feature Name')
plt.title('Logistic Regression Coefficients')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-167-2eb1e129b1fa> in <cell line: 2>()
#       1 coefficients = classifier['Logistic Regression'].coef_.flatten()
# ----> 2 feature_names = classifier['Logistic Regression'].feature_names_in_  # Replace these with your actual feature names
#       3
#       4 # Plotting the coefficients with feature names
#       5 plt.figure(figsize=(10, 6))
#
# AttributeError: 'LogisticRegression' object has no attribute 'feature_names_in_'

# %% [markdown]
# # Logistic Regression

# %%
model = LogisticRegression()
para= {
        'penalty':['l1', 'l2'],
        'C':[0.01, 0.03, 0.1, 1, 10]
      }
scores = [
    'f1',
    'recall']
results = []
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=5, n_iter=5)
  gs.fit(X,y)

  model.set_params(**gs.best_params_)
  model.fit(X,y)

  #model.fit(X_train, y_train)  # Train model

  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = round(accuracy_score(y_train, y_train_pred), 2)
  accuracy_valid = round(accuracy_score(y_valid, y_valid_pred), 2)
  accuracy_test = round(accuracy_score(y_test, y_test_pred), 2)

  precision_train = round(precision_score(y_train, y_train_pred), 2)
  precision_valid = round(precision_score(y_valid, y_valid_pred), 2)
  precision_test = round(precision_score(y_test, y_test_pred), 2)

  recall_train = round(recall_score(y_train, y_train_pred), 2)
  recall_valid = round(recall_score(y_valid, y_valid_pred), 2)
  recall_test = round(recall_score(y_test, y_test_pred), 2)

  f1_train = round(f1_score(y_train, y_train_pred), 2)
  f1_valid = round(f1_score(y_valid, y_valid_pred), 2)
  f1_test = round(f1_score(y_test, y_test_pred), 2)

  # Create a DataFrame for the current score type
  metrics_dict = {
      'Score Type': [score] * 4,
      'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
      'Train': [accuracy_train, precision_train, recall_train, f1_train],
      'Validation': [accuracy_valid, precision_valid, recall_valid, f1_valid],
      'Test': [accuracy_test, precision_test, recall_test, f1_test]
  }

  # Convert the dictionary to a DataFrame
  metrics_df = pd.DataFrame(metrics_dict)

  # Append the results to the list of results
  results.append(metrics_df)

# Concatenate the list of DataFrames into a single DataFrame
  final_results = pd.concat(results, ignore_index=True)  # ignore_index=True resets the index

# Print the final results
final_results

# %%
transposed_results = final_results.T

# Alternatively, you can use the transpose() method
# transposed_results = final_results.transpose()

# Print the transposed DataFrame
transposed_results

# %%
df = pd.DataFrame({'Model_Scores': model_scores})

# Print the DataFrame
print(df)

# %%
df = pd.DataFrame(gs.cv_results_)
df[['param_penalty', 'param_C','mean_test_score']]

# %% [markdown]
# # K Nearest Neighbors

# %%
model = KNeighborsClassifier()
para= {
        'n_neighbors': np.arange(13,50).tolist()
      }
scores = [
    'accuracy',
    'balanced_accuracy',
    'f1',
    'f1_weighted',
    'precision',
    'recall',
    'roc_auc']
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=5)
  gs.fit(X,y)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model

  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)
  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs

# %% [markdown]
# # Support Vector Machine

# %%
model = SVC()
para = {
    'C': [0.1, 1],
    'kernel': ['linear', 'rbf'],
    'gamma': [0.1, 1]
}


scores = [
    'f1'
    ]
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=3,n_iter=5, random_state=42)
  gs.fit(X_train,y_train)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model

  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)


  from sklearn.metrics import classification_report

# ...

# After you've obtained your predictions and true labels
  print("Classification Report training set:")
  print(classification_report(y_train, y_train_pred))

  print("Classification Report validation set:")
  print(classification_report(y_valid, y_valid_pred))

  print("Classification Report test set:")
  print(classification_report(y_test, y_test_pred))

  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs

# %% [markdown]
# # Naive Bayes GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
para = {
   'var_smoothing': np.logspace(-9, 0, 100)
}

scores = [
    'f1'
    ]
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=3,n_iter=10, random_state=42)
  gs.fit(X,y)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model

  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)
  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs

# %% [markdown]
# # Decision Tree Classifier

# %%
model = DecisionTreeClassifier()
para = {}


scores = [
    'recall'
    ]
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=5,n_iter=10, random_state=42)
  gs.fit(X_train,y_train)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model

  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)


  from sklearn.metrics import classification_report

# ...

# After you've obtained your predictions and true labels
  print("Classification Report training set:")
  print(classification_report(y_train, y_train_pred))

  print("Classification Report validation set:")
  print(classification_report(y_valid, y_valid_pred))

  print("Classification Report test set:")
  print(classification_report(y_test, y_test_pred))

  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs
# Out:
# Metrics Name: recall
# Best Parameters: {}
# Accuracy Training: 1.0
# Accuracy Validation: 0.89
# Accuracy Test: 0.89
# Precision Validation: 0.49
# Precision Test: 0.49
# Recall: 0.52
# F1 Score: 0.5
# Confusion Matrix:
# [[6812  496]
#  [ 448  480]]
# Classification Report training set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21922
#            1       1.00      1.00      1.00      2783
#
#     accuracy                           1.00     24705
#    macro avg       1.00      1.00      1.00     24705
# weighted avg       1.00      1.00      1.00     24705
#
# Classification Report validation set:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      7307
#            1       0.49      0.51      0.50       928
#
#     accuracy                           0.89      8235
#    macro avg       0.72      0.72      0.72      8235
# ...

# %%
# Assuming 'model' is your trained classifier
threshold = 0.3  # You can adjust this threshold value
y_test_prob = model.predict_proba(X_test)[:, 1]
y_test_pred_threshold = (y_test_prob > threshold).astype(int)

precision = precision_score(y_test, y_test_pred_threshold)
recall = recall_score(y_test, y_test_pred_threshold)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# Precision: 0.3543244320446393
# Recall: 0.9579741379310345

# %% [markdown]
# # Random Forest

# %%
model = RandomForestClassifier()
para = para = {
    'n_estimators': [100, 200, 300, 600],  # Try different numbers of trees
    'criterion': ['gini'],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [None, 10, 20],  # Limit the maximum depth of trees
    'min_samples_split': [2, 5, 10],  # Adjust minimum samples split
    'min_samples_leaf': [1, 2, 4]  # Adjust minimum leaf samples
}


scores = [
    'recall']
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=5,n_iter=10, random_state=42)
  gs.fit(X,y)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model

  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = round(accuracy_score(y_train, y_train_pred), 2)
  accuracy_valid = round(accuracy_score(y_valid, y_valid_pred), 2)
  accuracy_test = round(accuracy_score(y_test, y_test_pred), 2)

  precision_train = round(precision_score(y_train, y_train_pred), 2)
  precision_valid = round(precision_score(y_valid, y_valid_pred), 2)
  precision_test = round(precision_score(y_test, y_test_pred), 2)

  recall_train = round(recall_score(y_train, y_train_pred), 2)
  recall_valid = round(recall_score(y_valid, y_valid_pred), 2)
  recall_test = round(recall_score(y_test, y_test_pred), 2)

  f1_train = round(f1_score(y_train, y_train_pred), 2)
  f1_valid = round(f1_score(y_valid, y_valid_pred), 2)
  f1_test = round(f1_score(y_test, y_test_pred), 2)

  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {accuracy_train}')
  print(f'Accuracy Validation: {accuracy_valid}')
  print(f'Accuracy Test: {accuracy_test}')
  print(f'Precision Training: {precision_train}')
  print(f'Precision Validation: {precision_valid}')
  print(f'Precision Test: {precision_test}')
  print(f'Recall Training: {recall_train}')
  print(f'Recall Validation: {recall_valid}')
  print(f'Recall Test: {recall_test}')
  print(f'F1 Score Training: {f1_train}')
  print(f'F1 Score Validation: {f1_valid}')
  print(f'F1 Score Test: {f1_test}')
  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs

# %% [markdown]
# # AdaBoost Classifier

# %%
model = AdaBoostClassifier()
para = {
            'n_estimators': [128,256],
            'learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.3, 1.0]
        }


scores = [
    'recall']
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=5,n_iter=10, random_state=42)
  gs.fit(X,y)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model

  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)


  from sklearn.metrics import classification_report

# ...

# After you've obtained your predictions and true labels
  print("Classification Report training set:")
  print(classification_report(y_train, y_train_pred))

  print("Classification Report validation set:")
  print(classification_report(y_valid, y_valid_pred))

  print("Classification Report test set:")
  print(classification_report(y_test, y_test_pred))

  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs

# %% [markdown]
# # XGboost

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from scipy.stats import randint, uniform

# %%
ratio = float(np.sum(y_train == 0)) /(5*np.sum(y_train == 1))
model = XGBClassifier(scale_pos_weight=ratio)
para = {
    'learning_rate': [0.1, 0.01, 0.05, 0.001],
    'n_estimators': [8, 16, 32, 64, 128, 256],
    'max_depth': randint(3, 19),  # Random integer between 3 and 18
    'gamma': uniform(1, 9),  # Random float between 1 and 10
    'reg_alpha': randint(40, 181),  # Random integer between 40 and 180
    'reg_lambda': uniform(0, 1),  # Random float between 0 and 1
    'colsample_bytree': uniform(0.5, 0.5),  # Random float between 0.5 and 1
    'min_child_weight': randint(0, 11)  # Random integer between 0 and 10
}


scores = [
    'recall']

# %%
model = XGBClassifier()
para = {
    'learning_rate': [0.1, 0.01, 0.05, 0.001],
    'n_estimators': [8, 16, 32, 64, 128, 256],
    'max_depth': randint(3, 19),  # Random integer between 3 and 18
    'gamma': uniform(1, 9),  # Random float between 1 and 10
    'reg_alpha': randint(40, 181),  # Random integer between 40 and 180
    'reg_lambda': uniform(0, 1),  # Random float between 0 and 1
    'colsample_bytree': uniform(0.5, 0.5),  # Random float between 0.5 and 1
    'min_child_weight': randint(0, 11)  # Random integer between 0 and 10
}


scores = [
    'recall']
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=3,n_iter=10, random_state=42, error_score='raise')
  gs.fit(X,y)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model
  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)


  from sklearn.metrics import classification_report

# ...

# After you've obtained your predictions and true labels
  print("Classification Report training set:")
  print(classification_report(y_train, y_train_pred))

  print("Classification Report validation set:")
  print(classification_report(y_valid, y_valid_pred))

  print("Classification Report test set:")
  print(classification_report(y_test, y_test_pred))

  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs

# %%
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=3,n_iter=10, random_state=42, error_score='raise')
  gs.fit(X,y)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model
  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)


  from sklearn.metrics import classification_report

# ...

# After you've obtained your predictions and true labels
  print("Classification Report training set:")
  print(classification_report(y_train, y_train_pred))

  print("Classification Report validation set:")
  print(classification_report(y_valid, y_valid_pred))

  print("Classification Report test set:")
  print(classification_report(y_test, y_test_pred))

  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs

# %%
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=3,n_iter=10, random_state=42, error_score='raise')
  gs.fit(X,y)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model
  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)


  from sklearn.metrics import classification_report

# ...

# After you've obtained your predictions and true labels
  print("Classification Report training set:")
  print(classification_report(y_train, y_train_pred))

  print("Classification Report validation set:")
  print(classification_report(y_valid, y_valid_pred))

  print("Classification Report test set:")
  print(classification_report(y_test, y_test_pred))

  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Assuming y_test and y_pred_proba are available from your model
y_pred_proba = model.predict_proba(X_test)[:, 1]

precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

# Plotting the precision-recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='b', linewidth=2)
plt.xlabel('Recall', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.title('Precision-Recall Curve', fontsize=16)
plt.grid(True)
plt.show()

# Find the threshold where recall is high and precision is acceptable
high_recall_threshold = thresholds[recall >= 0.9].min()

# Apply the threshold to predict classes
y_pred_high_recall = (y_pred_proba >= high_recall_threshold).astype(int)

# Calculate recall, precision, and other metrics
recall_high_threshold = recall_score(y_test, y_pred_high_recall)
precision_high_threshold = precision_score(y_test, y_pred_high_recall)
f1_high_threshold = f1_score(y_test, y_pred_high_recall)

print(f'High Recall Threshold: {high_recall_threshold}')
print(f'Recall with High Threshold: {recall_high_threshold:.2f}')
print(f'Precision with High Threshold: {precision_high_threshold:.2f}')
print(f'F1 Score with High Threshold: {f1_high_threshold:.2f}')

# %% [markdown]
# # Catboost

# %%
pip install category_encoders
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 2.6 MB/s eta 0:00:00
# ...

# %%
from category_encoders import TargetEncoder
X = df.drop(columns=['y'],axis=1)
encoder = TargetEncoder()
X_encoded = encoder.fit_transform(X, y)
X_train_temp, X_test, y_train_temp, y_test = train_test_split(X_encoded,y,stratify = y, test_size=0.20,random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_temp,y_train_temp,stratify = y_train_temp, test_size=0.25,random_state=42)

# %%
X = df.drop(columns=['y'],axis=1)

# %%
encoder = TargetEncoder()
X_encoded = encoder.fit_transform(X, y)

# %%
X_encoded
# Out:
#        age       job   marital  education   housing      loan   contact  \
# 0       56  0.100000  0.101716   0.102490  0.108783  0.113262  0.052324
# 1       57  0.081422  0.101716   0.108389  0.108783  0.113262  0.052324
# 2       37  0.081422  0.101716   0.108389  0.115864  0.113262  0.052324
# 3       40  0.129128  0.101716   0.082060  0.108783  0.113262  0.052324
# 4       56  0.081422  0.101716   0.108389  0.108783  0.109315  0.052324
# ...    ...       ...       ...        ...       ...       ...       ...
# 41183   73  0.252619  0.101716   0.113550  0.115864  0.113262  0.147389
# 41184   46  0.068951  0.101716   0.113550  0.108783  0.113262  0.147389
# 41185   56  0.252619  0.101716   0.138189  0.115864  0.113262  0.147389
# 41186   44  0.108325  0.101716   0.113550  0.108783  0.113262  0.147389
# 41187   74  0.252619  0.101716   0.113550  0.115864  0.113262  0.147389
#
#           month  day_of_week  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
X_train_temp, X_test, y_train_temp, y_test = train_test_split(X_encoded,y,stratify = y, test_size=0.20,random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_temp,y_train_temp,stratify = y_train_temp, test_size=0.25,random_state=42)

# %%
'''X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
X_test = preprocessor.transform(X_test)
X = preprocessor.transform(X)'''
# Out:
# 'X_train = preprocessor.fit_transform(X_train)\nX_valid = preprocessor.transform(X_valid)\nX_test = preprocessor.transform(X_test)\nX = preprocessor.transform(X)'

# %%
model = CatBoostClassifier(verbose=False)
para = {
            'iterations': np.arange(100, 1300, 100).tolist(),
            'learning_rate': [0.001, 0.004, 0.01, 0.1, 0.2, 0.3],
            'depth': np.arange(1, 11).tolist(),
            'l2_leaf_reg': [1, 3, 5, 7, 9],
            'boosting_type': ['Ordered', 'Plain']
        }


scores = [
    'recall'
    ]
for score in scores:
  gs = RandomizedSearchCV(model, para, scoring = score, cv=5,n_iter=10, random_state=42)
  gs.fit(X_encoded,y)

  model.set_params(**gs.best_params_)
  model.fit(X_train,y_train)

  #model.fit(X_train, y_train)  # Train model

  y_train_pred = model.predict(X_train)
  y_valid_pred = model.predict(X_valid)
  y_test_pred = model.predict(X_test)


  accuracy_train = accuracy_score(y_train, y_train_pred)
  accuracy_valid = accuracy_score(y_valid, y_valid_pred)
  accuracy_test = accuracy_score(y_test, y_test_pred)
  precision_valid = precision_score(y_valid, y_valid_pred)
  precision = precision_score(y_test, y_test_pred)
  recall = recall_score(y_test, y_test_pred)
  f1 = f1_score(y_test, y_test_pred)
  confusion = confusion_matrix(y_test, y_test_pred)
  print(f"Metrics Name: {score}")
  print("Best Parameters:", gs.best_params_)
  print(f'Accuracy Training: {round(accuracy_train, 2)}')
  print(f'Accuracy Validation: {round(accuracy_valid, 2)}')
  print(f'Accuracy Test: {round(accuracy_test, 2)}')
  print(f'Precision Validation: {round(precision_valid, 2)}')
  print(f'Precision Test: {round(precision, 2)}')
  print(f'Recall: {round(recall, 2)}')
  print(f'F1 Score: {round(f1, 2)}')
  print('Confusion Matrix:')
  print(confusion)


  from sklearn.metrics import classification_report

# ...

# After you've obtained your predictions and true labels
  print("Classification Report training set:")
  print(classification_report(y_train, y_train_pred))

  print("Classification Report validation set:")
  print(classification_report(y_valid, y_valid_pred))

  print("Classification Report test set:")
  print(classification_report(y_test, y_test_pred))

  print("\n" + "="*50 + "\n")  # Separating different runs with equal signs
# Out:
# Metrics Name: recall
# Best Parameters: {'learning_rate': 0.2, 'l2_leaf_reg': 7, 'iterations': 600, 'depth': 1, 'boosting_type': 'Plain'}
# Accuracy Training: 0.91
# Accuracy Validation: 0.91
# Accuracy Test: 0.91
# Precision Validation: 0.66
# Precision Test: 0.65
# Recall: 0.47
# F1 Score: 0.55
# Confusion Matrix:
# [[7076  232]
#  [ 493  435]]
# Classification Report training set:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     21922
#            1       0.67      0.47      0.55      2783
#
#     accuracy                           0.91     24705
#    macro avg       0.80      0.72      0.75     24705
# weighted avg       0.91      0.91      0.91     24705
#
# Classification Report validation set:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      7307
#            1       0.66      0.45      0.53       928
#
#     accuracy                           0.91      8235
# ...

# %% [markdown]
# # Experiment section

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# ... (previous code remains unchanged)

# Calculate ROC curve for test set
y_test_probs = model.predict_proba(X_test)[:, 1]  # Probabilities for positive class
fpr, tpr, thresholds = roc_curve(y_test, y_test_probs)
roc_auc = roc_auc_score(y_test, y_test_probs)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# ... (rest of your code remains unchanged)

# %%
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

# %%
distances = np.sqrt((fpr - 0)**2 + (tpr - 1)**2)
optimal_idx = np.argmax(distances)
optimal_threshold = thresholds[optimal_idx]

# %%
desired_sensitivity = 0.93
optimal_idx = np.argmax(tpr >= desired_sensitivity)
optimal_threshold = thresholds[optimal_idx]

# %%
optimal_threshold

# %%
print("Best Parameters: ", report["Best Parameters"])
print(f"Accuracy: {report['accuracy']}")
print(f"Precision: {report['precision']}")
print(f"Recall: {report['recall']}")
print(f"F1 Score: {report['f1']}")
print("Confusion Matrix:")
for row in report['confusion matrix']:
    print(" ".join(str(item) for item in row))
